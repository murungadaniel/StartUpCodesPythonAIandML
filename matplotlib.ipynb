# %% [markdown]
# ##### Loading the libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ##### Basic graph

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##### Adding a x and y label

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y)
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.show()

# %% [markdown]
# ##### Resizing the font of the title

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y)
plt.title('Innodems',fontdict = {'fontsize':15,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.show()

# %% [markdown]
# ##### changing the ticks to integers number only

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y)
plt.title('Our first title',fontdict = {'fontsize':20,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.xticks([1,2,3,4,5])
plt.yticks([6,7,8,9,10])
plt.show()

# %% [markdown]
# ##### Adding a legend

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y,label='Straight Line passing though the origin')
plt.title('Our first title',fontdict = {'fontsize':20,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.xticks([1,2,3,4,5])
plt.yticks([6,7,8,9,10])
plt.legend() #we first specify the label in plot() function
plt.show()

# %% [markdown]
# ##### Changing the color of the line

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y,label='Straight Line',color='green')
plt.title('Our first title',fontdict = {'fontsize':20,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.xticks([1,2,3,4,5])
plt.yticks([6,7,8,9,10])
plt.legend() #we first specify the label in plot() function
plt.show()

# %% [markdown]
# ##### Changing the linewidth of the line

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y,label='Straight Line',color='red',linewidth=4)
plt.title('Our first title',fontdict = {'fontsize':20,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.xticks([1,2,3,4,5])
plt.yticks([6,7,8,9,10])
plt.legend() #we first specify the label in plot() function
plt.show()

# %% [markdown]
# ###### Using a different marker

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y,label='Straight Line',color='red',linewidth=1,marker='>',markersize=10)
plt.title('Our first title',fontdict = {'fontsize':20,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.xticks([1,2,3,4,5])
plt.yticks([6,7,8,9,10])
plt.legend() #we first specify the label in plot() function
plt.show()

# %% [markdown]
# ##### marker with different color

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y,label='Straight Line',
         color='red',linewidth=1,marker='+',
         markersize=10,markeredgecolor='blue')
plt.title('Our first title',fontdict = {'fontsize':20,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.xticks([1,2,3,4,5])
plt.yticks([6,7,8,9,10])
plt.legend() #we first specify the label in plot() function
plt.show()

# %% [markdown]
# ##### Short hand notation in plot function

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y,'+--g',label='Straight Line')
plt.title('Our first title',fontdict = {'fontsize':20,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.xticks([1,2,3,4,5])
plt.yticks([6,7,8,9,10])
plt.legend() #we first specify the label in plot() function
plt.show()

# %% [markdown]
# ##### Adding another line to the plot

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y,'+--r',label='Straight Line')

x2 = np.arange(1,4.5,0.5)
plt.plot(x2[:5],x2[:5]**2,'b',label='x^2')
plt.plot(x2[4:],x2[4:]**2,'b--')
plt.title('Our first title',fontdict = {'fontsize':20,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.xticks([1,2,3,4,5])
plt.yticks([6,7,8,9,10])
plt.legend() #we first specify the label in plot() function
plt.show()

# %% [markdown]
# ##### Resize the figure

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
#Resize the graph
plt.figure(figsize=(5,3))
plt.plot(x,y,'+--r',label='Straight Line')

x2 = np.arange(1,4.5,0.5)
plt.plot(x2[:5],x2[:5]**2,'b',label='x^2')
plt.plot(x2[4:],x2[4:]**2,'b--')
plt.title('Our first title',fontdict = {'fontsize':20,'fontweight':'bold'})
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.xticks([1,2,3,4,5])
plt.yticks([6,7,8,9,10])
plt.legend() #we first specify the label in plot() function
plt.show()
